# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!) и в них я буду стараться ответить на твои вопросы, если таковые увижу (мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте).
#
# ………………
#
# Софья, вижу, что все красные комментарии учтены, код исправлен, выводы актуализированы. Соответственно никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня более нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Привет Софья!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике. Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что в следующий раз можно сделать по-другому. "Жёлтые" комментарии не требуют твоих правок в проекте и их наличие НИКАК не повлияет на результат моей проверки. Но я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет.
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные недочёты в проектах:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
# # Анализ критериев успешности видеоигр

# %% [markdown]
# Из открытых источников нам доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы до 2016 года. Цель - проанализировать данные и выявить определяющие успешность игры закономерности для прогноза продаж на 2017 год. Этот проект включает в себя предобработку данных, исследовательский анализ, выдвижение и проверку гипотез.

# %% [markdown]
# ## Изучение данных

# %% [markdown]
# Импортируем библиотеки, загрузим данные и изучим первые 10 строк.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import re
from scipy import stats as st

# %%
df = pd.read_csv('/datasets/games.csv')
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Ознакомимся с общей информацией о столбцах.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
for col in df.columns:    
    if df[col].dtype =="object":    
        print(col)
        print(df[col].unique())
        print()
# Out:
# Name
# ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
#
# Platform
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# Genre
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' nan]
#
# User_Score
# ['8' nan '8.3' '8.5' '6.6' '8.4' '8.6' '7.7' '6.3' '7.4' '8.2' '9' '7.9'
#  '8.1' '8.7' '7.1' '3.4' '5.3' '4.8' '3.2' '8.9' '6.4' '7.8' '7.5' '2.6'
#  '7.2' '9.2' '7' '7.3' '4.3' '7.6' '5.7' '5' '9.1' '6.5' 'tbd' '8.8' '6.9'
#  '9.4' '6.8' '6.1' '6.7' '5.4' '4' '4.9' '4.5' '9.3' '6.2' '4.2' '6' '3.7'
#  '4.1' '5.8' '5.6' '5.5' '4.4' '4.6' '5.9' '3.9' '3.1' '2.9' '5.2' '3.3'
#  '4.7' '5.1' '3.5' '2.5' '1.9' '3' '2.7' '2.2' '2' '9.5' '2.1' '3.6' '2.8'
# ...

# %% [markdown]
# Итак, датафрейм содержит 11 колонок со следующей информацией:
# - `Name` — название игры
# -`Platform` — платформа
# -`Year_of_Release` — год выпуска от 1980 до 2016
# -`Genre` — жанр игры
# -`NA_sales` — продажи в Северной Америке (миллионы проданных копий)
# -`EU_sales` — продажи в Европе (миллионы проданных копий)
# -`JP_sales` — продажи в Японии (миллионы проданных копий)
# -`Other_sales` — продажи в других странах (миллионы проданных копий)
# -`Critic_Score` — оценка критиков (максимум 100)
# -`User_Score` — оценка пользователей (максимум 10)
# -`Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <b>Предложение 👉</b>
#
# **df.duplicated().sum() == 0** не означает, что в данных нет дубликатов (записей).
#
# Попробуй найти неявные дубликаты (для их поиска нужно  использовать параметр **subset**). Ну а в нашем рабочем проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# Как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, добавила </font>
# </div>

# %% [markdown]
# Попробуем найти неявные дубликаты для пары "Имя-Игровая консоль" (имена игр могут повторяться, т.к. одна игра может быть выпущена для разных консолей).

# %%
df[df.duplicated(subset=['Name','Platform'])].sort_values(by='Name')
# Out:
#                               Name Platform  Year_of_Release     Genre  \
# 16230                Madden NFL 13      PS3           2012.0    Sports
# 1591   Need for Speed: Most Wanted     X360           2005.0    Racing
# 11715  Need for Speed: Most Wanted       PC           2012.0    Racing
# 4127            Sonic the Hedgehog      PS3              NaN  Platform
# 14244                          NaN      GEN           1993.0       NaN
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 16230       0.0      0.01      0.00         0.00          83.0        5.5
# 1591        1.0      0.13      0.02         0.10          83.0        8.5
# 11715       0.0      0.06      0.00         0.02          82.0        8.5
# 4127        0.0      0.48      0.00         0.00          43.0        4.1
# 14244       0.0      0.00      0.03         0.00           NaN        NaN
#
#       Rating
# 16230      E
# 1591       T
# 11715      T
# 4127    E10+
# 14244    NaN

# %% [markdown]
# **Вывод**
#
# 1. Названия столбцов следует привести к нижнему регистру.
# 2. Поле `User_Score` имеет неверный тип данных. В данной колонке содержатся числовые данные (оценка пользователя от 0 до 10), но тип данных `object` из-за текстового значения `tbd` (англ. to be done). Видимо, это техническая отметка, обозначающая, что информации по данным играм ещё нет, её можно заменить на пустое значение.
# 3. Есть пропуски в `Name`, `Year_of_Release` и `Genre`, которые можно попытаться восстановить.
# 4. Пропуски в `Rating`, скорее всего, вызваны тем, что рейтинговое агентство ESRB оценивает только определённые игры, т.к. базируется в Америке и Канаде. Оценки критиков для игр, которые там непопулярны, отсутствуют.
# 5. Колонки `Critic_Score` и `User_Score` заполнены примерно наполовину - видимо, не все игры были оценены критиками и пользователями или же оценки не были подгружены в датасет, в любом случае восстановить отсутствующие данные в рамках исследования не представляется возможным.
# 6. В целях исследования значения рейтинга нужно обобщить до минимального количества категорий.
# 7. Явных дублей в датасете не обнаружено, но обнаружено несколько дублей пар значений название-платформа.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Приведем к нижнему регистру названия столбцов.

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# Изучим полученные 3 дублирующиеся игры (значение NaN будет обработано позже во время работы с пропусками).

# %%
df[df['name']=='Madden NFL 13']
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 507    Madden NFL 13     X360           2012.0  Sports      2.53      0.15
# 604    Madden NFL 13      PS3           2012.0  Sports      2.11      0.22
# 3986   Madden NFL 13      Wii           2012.0  Sports      0.47      0.00
# 5887   Madden NFL 13      PSV           2012.0  Sports      0.28      0.00
# 7066   Madden NFL 13     WiiU           2012.0  Sports      0.21      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports      0.00      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 507         0.0         0.17          81.0        5.8      E
# 604         0.0         0.23          83.0        5.5      E
# 3986        0.0         0.03           NaN        7.3      E
# 5887        0.0         0.02          63.0        7.3      E
# 7066        0.0         0.02          75.0        6.7      E
# 16230       0.0         0.00          83.0        5.5      E

# %%
df[df['name']=='Need for Speed: Most Wanted']
# Out:
#                               name platform  year_of_release   genre  \
# 253    Need for Speed: Most Wanted      PS2           2005.0  Racing
# 523    Need for Speed: Most Wanted      PS3           2012.0  Racing
# 1190   Need for Speed: Most Wanted     X360           2012.0  Racing
# 1591   Need for Speed: Most Wanted     X360           2005.0  Racing
# 1998   Need for Speed: Most Wanted       XB           2005.0  Racing
# 2048   Need for Speed: Most Wanted      PSV           2012.0  Racing
# 3581   Need for Speed: Most Wanted       GC           2005.0  Racing
# 5972   Need for Speed: Most Wanted       PC           2005.0  Racing
# 6273   Need for Speed: Most Wanted     WiiU           2013.0  Racing
# 6410   Need for Speed: Most Wanted       DS           2005.0  Racing
# 6473   Need for Speed: Most Wanted      GBA           2005.0  Racing
# 11715  Need for Speed: Most Wanted       PC           2012.0  Racing
#
# ...

# %%
df[df['name']=='Sonic the Hedgehog']
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 257   Sonic the Hedgehog      GEN           1991.0  Platform      3.03
# 1745  Sonic the Hedgehog      PS3           2006.0  Platform      0.41
# 1996  Sonic the Hedgehog     X360           2006.0  Platform      0.44
# 4127  Sonic the Hedgehog      PS3              NaN  Platform      0.00
#
#       eu_sales  jp_sales  other_sales  critic_score user_score rating
# 257       0.91      0.26         0.13           NaN        NaN    NaN
# 1745      0.06      0.04         0.66          43.0        4.1   E10+
# 1996      0.48      0.00         0.11          46.0        4.4   E10+
# 4127      0.48      0.00         0.00          43.0        4.1   E10+

# %% [markdown]
# `Need for Speed: Most Wanted` выпускалась два раза - в 2005 и в 2012 году, а для остальных двух игр стоит сложить продажи и удалить дублирующиеся строки.

# %%
df.loc[1745,'eu_sales'] += 0.48
df.loc[604,'eu_sales'] += 0.01
df = df.drop(4127)
df = df.drop(604)

# %% [markdown]
# Заменим тип данных в колонке `user_score`, применив метод `to_numeric` с параметром `errors='coerce'`, чтобы удалить все  значения `tbd`.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Прежде чем производить какие-либо модификации данных (удалять пропуски, заполнять пропуски «заглушкой) хотелось бы порассуждать на тему природы пропусков в наших данных.
#
# Одна из задач этого проекта (согласно брифа):
#
# 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать,
#
# 2. Опишите причины, которые могли привести к пропускам
#
# 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать.
#
# 4. Также, скажи пожалуйста, какова на твой взгляд причина того, что в столбце с оценками экспертов, с оценками пользователей и с рейтингами так много пропусков? Как ты считаешь, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство?</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, добавила пункт 4 в вывод выше </font>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# В серьёзном и важном продакшн коде я бы не стал сразу использовать errors='coerce', а вначале бы явно "прогнал код" используя errors='raise' (ну или вообще удалив errors=..., потому что 'raise' 'это значение по умолчанию). Почему? Потому что errors='coerce' все "неправильные" значения сделает NaN и никаких сообщений об этом не будет, т.е. потенциально данные в серии 'user_score' мы можем испортить.</div>

# %%
print('Всего текстовых значений: ', df[df['user_score']=='tbd']['user_score'].count())
# Out:
# Всего текстовых значений:  2424

# %%
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16711 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16445 non-null  float64
#  3   genre            16711 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8135 non-null   float64
#  9   user_score       7588 non-null   float64
#  10  rating           9947 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Теперь тип данных корректен, а количество оценок пользователей сократилось до 7,5 тысяч.
#
# Изучим строки с пропущенными названиями, жанрами и годами выпуска игр.

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %% [markdown]
# Восстановить пропущенные жанры и названия игры невозможно, их можно заменить на `unknown`.

# %%
df['name'] = df['name'].fillna('unknown')
df['genre'] = df['genre'].fillna('unknown')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Я бы после анализа удалил эти записи. Их всего 269 (из 16+ тысяч), меньше 2%. "Погоды" они нам не сделают.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# (Немного рассуждений): да, всего 2 записи (из 16 тысяч) с пропусками в жанрах и названиях (плюс в этих же записях нет ни оценок пользователей, ни оценок критиков, ни рейтингов) и 269 записей (менее 2% из 16+ тысяч) с пропусками в годах выпуска. Надо удалять даже не раздумывая …
#
# Хотя конечно, единого сценария нет на самом деле. С одной стороны - да, говорят, что "данных много не бывает", удалять записи из-за пропусков, когда датасет измеряется сотнями-тысячами записей ой как не хочется.
#
# С другой стороны, если запись не спасти, если в ней несколько полей не заполнено или не заполнены ключевые поля, и ты чувствуешь, что заполнение их медианами/средними приведёт к смещению статистик - надо удалять. Да, можно поставить "заглушку", но тогда надо отдавать отчёт, что во всем последующем коде про эту "заглушку" помнить придётся. Т.е. перед построением всех графиков, гистограмм заглушку надо будет удалить. Перед расчетом корреляций - заглушку надо будет удалить. Перед проверкой гипотез заглушку надо будет удалить.
#
# Я бы так определил способ решения такой задачи: если записи с пропусками в ключевых для моего анализа полях составляют 1-3-5-до 10% строк, то я бы их из оригинального датафрейма вырезал (но сохранил бы в некий df, к которому при необходимости мог бы обратиться).
#
# А вообще, в таких случаях, когда нужно решить - заполнять пропуски или удалять строки с ними из df - всегда ищи эксперта в предметной области и советуйся с ним. Как правило это человек из бизнеса, который значит суть бизнес-процесса и вот именно он даст тебе точный и аргументированный совет - что в данной, конкретной задаче делать с "битыми" полями в строках датафрейма.</div>

# %% [markdown]
# Посмотрим, сколько всего пропусков года выпуска.

# %%
'Всего пропусков года выпуска: {:.1%}'.format((df['year_of_release'].isna().sum())/len(df))
# Out:
# 'Всего пропусков года выпуска: 1.6%'

# %% [markdown]
# Восстановим часть пропущенных годов по следующим правилам:
# - если у игры есть версия для других платформ, возьмём год выпуска оттуда;
# - иначе, попробуем восстановить год выпуска из поля `name`, т.к. иногда он указывается в самом названии игры.
#
# Напишем функцию, которая будет восстанавливать года, последовательно применяя правила выше.

# %%
def find_year(row):
    year_of_release = row['year_of_release']
    if pd.isna(year_of_release):
        try:
            year_of_release = df[(df['name']==row['name'])&
                              ~(df['year_of_release'].isna())]['year_of_release'].max()
        except:
            if re.search('20..|19..', row['name']):
                year_of_release = int(re.findall('20..|19..', row['name'])[0])
    return year_of_release

# %%
df['year_of_release']=df.apply(find_year, axis=1)

# %%
'Всего пропусков года выпуска: {:.1%}'.format((df['year_of_release'].isna().sum())/len(df))
# Out:
# 'Всего пропусков года выпуска: 0.9%'

# %% [markdown]
# У нас получилось снизить количество пропусков до одного процента, эти строки можно удалить.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Я бы после анализа удалил эти записи. Их всего 269 (из 16+ тысяч), меньше 2%. "Погоды" они нам не сделают, а написание такого кода всё равно требует времени на написание и отладку.
#
# p.s. ну и тем более, все 269 пропусков заполнить не удалось, всё равно в итоге 146 записей остались с пропусками в поле года выпуска.</div>

# %%
df= df.dropna(subset=['year_of_release'])

# %%
df['year_of_release'] = df['year_of_release'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16567 non-null  object
#  1   platform         16567 non-null  object
#  2   year_of_release  16567 non-null  int64
#  3   genre            16567 non-null  object
#  4   na_sales         16567 non-null  float64
#  5   eu_sales         16567 non-null  float64
#  6   jp_sales         16567 non-null  float64
#  7   other_sales      16567 non-null  float64
#  8   critic_score     8073 non-null   float64
#  9   user_score       7538 non-null   float64
#  10  rating           9866 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# В первых 8 колонках датафрейма больше нет пропусков, типы данных корректны.

# %% [markdown]
# Категоризируем значения рейтинга в колонке `rating`.
#
# Согласно Википедии, существуют следующие знаки рейтинга ESRB:
# - `EC` (Early childhood) — игра подходит для детей от 3 лет
# - `E` (Everyone) — для всех. Первоначально `K-A` (Kids to Adults)
# - `E10+` (Everyone 10 and older) — для всех от 10 лет и старше
# - `T` (Teen) — для лиц от 13 лет
# - `M` (Mature) — для взрослых, материалы игры не подходят для подростков младше 17 лет
# - `AO` (Adults Only 18+) — только для взрослых старше 18 лет
# - `RP` (Rating Pending) — рейтинг ожидается: продукт был отправлен в ESRB и ожидает присвоения рейтинга.
#
#
# 1. `EC`, `E`, `K-A` и `E10+` объединим в одну категорию `E`
# 2. `AO` включим в `M`
# 3. `RP` заменим на значение `unknown`.

# %%
df['rating'] = df['rating'].replace('AO','M')
df['rating'] = df['rating'].replace('E10+','E')
df['rating'] = df['rating'].replace('EC','E')
df['rating'] = df['rating'].replace('K-A','E')
df['rating'] = df['rating'].replace('RP','unknown')

# %% [markdown]
# Напишем функцию, которая частично заполнит отсутствующие рейтинги по следующим правилам:
# - если у игры есть версия для других платформ, возьмём рейтинг оттуда;
# - остальные пропуски заменим на `unknown`.

# %%
def find_rating(row):
    rating = row['rating']
    if pd.isna(rating):
        try:
            rating = df[(df['name']==row['name'])&
                              ~(df['rating'].isna())]['rating'].iloc[0]
        except:
            rating = 'unknown'
    return rating

# %%
df['rating'] = df.apply(find_rating, axis=1)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# И здесь я не согласен с твоим способом замены, не согласен по 2-м моментам:
#
# 1. рейтинг ESRB выставляется **не** жанру, а отдельной игре,
#
# 2. Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство. Япония страна со своим менталитетом, верят только своим. Вообще, твой анализ должен показать, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень-то внимание обращают. А мы таким рейтингам получается проставили значение американского агентства.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16567 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16567 non-null  object
#  1   platform         16567 non-null  object
#  2   year_of_release  16567 non-null  int64
#  3   genre            16567 non-null  object
#  4   na_sales         16567 non-null  float64
#  5   eu_sales         16567 non-null  float64
#  6   jp_sales         16567 non-null  float64
#  7   other_sales      16567 non-null  float64
#  8   critic_score     8073 non-null   float64
#  9   user_score       7538 non-null   float64
#  10  rating           16567 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# С помощью функции удалось заполнить 1732 строки с отсутствующим рейтингом.
#
# Добавим в датафрейм ещё один столбец с суммарными продажами по всем регионам.

# %%
df['total_sales']=df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis='columns')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо </font>
# </div>

# %% [markdown]
# **Вывод**
#
# На этапе предобработки в данных обнаружились пропуски, которые были частично заполнены с помощью уже имеющихся в таблице данных, 1% данных с пропусками был удалён. Значения в столбце `rating` приведены к числовому типу с плавающей точкой, технические пометки исключены. Значения рейтинга игр категоризированы, добавлен расчёт итоговых продаж по всем регионам.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты в 'critic_score' и 'user_score' (после обращения tbd в NaN) оставляешь NaN'ы без обработки - значительно упростит тебе жизнь дальше. В этом проекте - это верное решение.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, принято правильное решение! «Заглушка» для NaN значений в столбце ‘rating’ – это верное решение в этом проекте. Далее, когда ты будешь анализировать особенности регионов в зависимости от рейтинга ESRB, то увидишь, что если бы они остались NaN, то на графиках их не было бы видно, также такие игры "выпали" бы из анализа и выводов, а это красная ошибка в этом проекте.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать и к EDA (== Exploratory Data Analysis).</div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Выделение актуального периода

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы.

# %%
df['year_of_release'].plot(kind='hist',
                           bins=37,
                           figsize=(16,8),
                           grid=True,
                          title='Распределение выпуска игр по годам',
                          )
plt.ylabel('Количество выпущенных игр')
plt.show()

# %% [markdown]
# Игровая индустрия начала существенно развиваться в конце второго тысячелетия - данные до 2000 года вряд ли могут помочь в исследовании. Пик выпуска игр зафиксирован в 2008 и 2009 годах.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Просто супер: график подписан, оси подписаны. Не часто на самом деле такой скрупулёзный подход к оформлению встречается. Молодец.</div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# было бы здорово здорово получить объяснение поведения данного графика. Пытаться понять полученный результат - важная часть работы аналитика.</div>

# %% [markdown]
# Исследуем, за какой срок появляются новые и исчезают старые игровые платформы. Для этого выберем платформы с наибольшими суммарными продажами и построим распределение по годам.

# %%
top_plat = df.groupby('platform')['total_sales'].sum().sort_values(ascending=False)
top_plat
# Out:
# platform
# PS2     1247.16
# X360     966.61
# PS3      932.63
# Wii      903.31
# DS       804.28
# PS       727.58
# PS4      314.14
# GBA      313.73
# PSP      293.57
# PC       258.86
# 3DS      258.53
# XB       256.69
# GB       254.43
# NES      251.05
# N64      218.48
# SNES     200.04
# GC       198.66
# XOne     159.32
# 2600      89.01
# WiiU      82.19
# PSV       53.81
# SAT       33.59
# GEN       30.77
# DC        15.95
# SCD        1.86
# NG         1.44
# WS         1.42
# TG16       0.16
# 3DO        0.10
# GG         0.04
# PCFX       0.03
# Name: total_sales, dtype: float64

# %% [markdown]
# Изучим распределение выпуска игр первых 18 платформ.

# %%
plat_life = []
for p in top_plat.head(18).index:
    print(p)
    df[df['platform']==p]['year_of_release'].hist()
    age = df[df['platform']==p]['year_of_release'].max()-df[df['platform']==p]['year_of_release'].min()
    plat_life.append(age)
    print('Срок существования платформы (в годах): ',age)   
    plt.show()
# Out:
# PS2
# Срок существования платформы (в годах):  11
# X360
# Срок существования платформы (в годах):  11
# PS3
# Срок существования платформы (в годах):  11
# Wii
# Срок существования платформы (в годах):  10
# DS
# Срок существования платформы (в годах):  28
# PS
# Срок существования платформы (в годах):  9
# PS4
# Срок существования платформы (в годах):  3
# GBA
# Срок существования платформы (в годах):  7
# PSP
# Срок существования платформы (в годах):  11
# PC
# Срок существования платформы (в годах):  31
# 3DS
# Срок существования платформы (в годах):  6
# XB
# Срок существования платформы (в годах):  8
# GB
# Срок существования платформы (в годах):  13
# NES
# Срок существования платформы (в годах):  11
# N64
# Срок существования платформы (в годах):  8
# SNES
# Срок существования платформы (в годах):  9
# GC
# Срок существования платформы (в годах):  6
# XOne
# Срок существования платформы (в годах):  3

# %%
print('Средний срок существования платформы (в годах): ', int(sum(plat_life)/len(plat_life)))
# Out:
# Средний срок существования платформы (в годах):  10

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Подтверждаю 7-9-11 лет, как корректный интервал, описывающий средний срок жизни игровой платформы.</div>

# %% [markdown]
# Среди всех платформ выделяется PC - персональные компьютеры - как самая старая и долгоживущая платформа. На ПК игры выпускают уже 31 год. Остальные платформы имеют тенденцию сменять друг друга. Причём характерный срок существования платформы - примерно 10 лет.
#
# Из общей картины также выбивается платформа DS, которая была выпущена в 2004 году, но согласно данным имеет срок жизни 28 лет.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Молодец! Да, это баг в данных. Игра выпущена в 1985 году на DS, когда DS ещё не было.
# </div>

# %%
df[(df['platform']=='DS')&(df['year_of_release']<2004)]
# Out:
#                                       name platform  year_of_release   genre  \
# 15957  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15957       0.0       0.0      0.02          0.0           NaN         NaN
#
#         rating  total_sales
# 15957  unknown         0.02

# %% [markdown]
# Очевидно, данная игра была добавлена в таблицу с неверным годом выпуска, на самом деле год её выпуска - 2010 (https://www.vgchartz.com/game/4399/strongest-tokyo-university-shogi-ds/). Исправим ошибку.

# %%
df.loc[15957, 'year_of_release'] = 2010

# %% [markdown]
# Цель исследования - изучить данные, способные предсказать продажи игр в 2017 году. Поэтому отсечём все данные по устаревшим и неактуальным платформам. То есть будем рассматривать только те платформы, которые вышли после 2013 года и для которых до сих пор выпускают игры (то есть есть хотя бы одна выпущенная в 2016 году игра).

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нет, здесь ты берешь для анализа слишком большой интервал.
#
# Для стремительно развивающейся игровой индустрии период > 3-4 лет — очень много. Внутри выбранного тобой периода произошли резкие изменения, например, произошла замена одного поколения консолей следующим (PS -> PS2 -> PS3 -> PS4). Некоторые платформы совсем исчезли (например, платформа DS не имеет новых релизов игр с 2013 года, PS2 с 2011 года, PSP с 2015 года). Как думаешь - помогут нам эти платформы построить прогноз на 2017 год или всё же лучше уменьшить интервал для анализа?
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем случае думаю, что 3 года: 2014, 2015 и неполный 2016 - ОК.
#
# Когда изменишь "горизонт" анализа и перезапустишь код в этой "тетрадке" - посмотри, как поменяется этот и все последующие выводы.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %%
df_2015 = df[df['year_of_release']>2013]
df_2015.groupby('platform')['year_of_release'].max()
# Out:
# platform
# 3DS     2016
# PC      2016
# PS3     2016
# PS4     2016
# PSP     2015
# PSV     2016
# Wii     2016
# WiiU    2016
# X360    2016
# XOne    2016
# Name: year_of_release, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Единственный момент, на будущее - когда делаешь срез из оригинального датафрейма старайся сохранять его под новым именем. Этим ты будешь гарантировать, что в **df** у тебя всегда находятся полные, ОРИГИНАЛЬНЫЕ, очищенные и предобработанные данные.
#
# **ПРИМЕР**: например, обрезая данные 2015 годом я бы сохранил их в новый датафрейм так (**псевдокод!**): **data_2015 = data[data['year_of_release']>=2014]**
#
# Далее/же продолжил бы работать с **data_2015** ... А теперь допустим ещё ниже мне понадобилось бы сделать другой срез, из полного оригинального датафрейма. И тогда я бы тогда написал что-нибудь типа: **data_before2000 = data[data['year_of_release'] <= 2000]**. И это бы сработало.
#
# А в твоём случае - нет, потому что в **df** у тебя теперь находится не полные оригинальные данные, а срез «выше» 2014 года. Мне удалось донести мысль? В общем порядок такой: загрузили данные из csv, обработали пропуски, почистили, сделали все необходимое и ОСТАВИЛИ для любых дальнейших обращений к нему. А для решения промежуточных локальных задач делай срезы из полного датафрейма, но сохраняй эти срезы под собственными именами (не перезатирай оригинальные данные).</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %% [markdown]
# Отсеим `PSP` - на ней уже не выпускают игры

# %%
df_2015 = df_2015[~(df_2015['platform']=='PSP')]

# %% [markdown]
# ### Популярные платформы

# %% [markdown]
# Исследуем, какие платформы лидируют по продажам, растут или падают и выберем потенциально самые успешные платформы.

# %%
df_2015.pivot_table(
    index='year_of_release',
    columns='platform',
    values='total_sales',
    aggfunc='sum').plot(
        title='Продажи по платформам',
        style='o-',
        figsize=(16, 8),
        alpha=0.6,
        linewidth=3,
        xlabel='Год выпуска',
        ylabel='Продажи, млн шт')
plt.show()

# %% [markdown]
# Спад продаж в 2016 году объясняется неполнотой данных в таблице за 2016 год, его не нужно брать во внимание.
#
# Самые успешные платформы - `PS4` и `XOne`, они появились недавно - в 2013 году, а продажи игр для них стабильно растут. По остальным платформам наблюдается плавный спад продаж.

# %%
df_2015.boxplot(column='total_sales',
           by='platform',
           figsize=(16,8))
plt.ylim(0, 5)
plt.xlabel('Платформа')
plt.ylabel('Продажи, млн шт')
plt.show()

# %%
df_2015.boxplot(column='total_sales',
           by='platform',
           figsize=(16,8))
plt.ylim(0, 1)
plt.xlabel('Платформа')
plt.ylabel('Продажи, млн шт')
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается. Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85). Ну и «строй» график большего размера (попробуй использовать: plt.figure(figsize=[20, 10]).
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, добавила еще один график с другим ограничением </font>
# </div>

# %% [markdown]
# Согласно диаграмме размаха выше, самая непопулярная платформа - `PSV`, продажи игр для этой платформы редко превышают 0,2 млн копий. А саммые коммерчески успешные платформы `PS4`, `XOne`,`WiiU` и их предшественницы `PS3`,`Wii` и `X360` характеризуются широким межквартильным размахом продаж игр (примерно 0,5 млн) и медианой на уровне 0,2 млн копий.

# %% [markdown]
# ### Какие факторы влияют на продажи

# %% [markdown]
# Перейдём к исследованию факторов, влияющих на продажи игр. Возьмём самую успешную платформу `PS4` и построим диаграмму рассеяния зависимости продаж от отзывов критиков и пользователей.

# %%
df_2015[df_2015['platform']=='PS4'].plot(x='user_score',
                               y='total_sales',
                               kind='scatter',
                               title='Зависимость продаж от пользовательских оценок',
                               figsize=(6,4),
                              ylabel='Продажи, млн шт',
                              xlabel='Оценка пользователей')

plt.show()

print('Коэффициент корреляции Пирсона: ', 
      df_2015[df_2015['platform']=='PS4']['total_sales'].corr(
          df_2015[df_2015['platform']=='PS4']['user_score']))
# Out:
# Коэффициент корреляции Пирсона:  -0.040131589472697356

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Это относиться также и к ячейкам ниже.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Тут всё верно, мы выбрали одну из платформ и проверили линейную зависимость между продажами и оценками пользователей и экспертов.
#
# И вот здесь именно то место, которое упрощает жизнь за счет того, что мы не заполняли пропуски в 'critic_score' и 'user_score'. Если бы это было иначе - перед анализом корреляций надо было бы эти заполненные значения не учитывать (отфильтровывать).
#
# Ввиду же того, что "пропуски" в столбцах с соответствующими оценками мы "заглушками" заполнять не стали (а NaN – значения метод .corr() не учитывает (ссылка на документацию: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html?highlight=corr#pandas.DataFrame.corr)), то и перед передачей данных в метод .corr() отфильтровывать нам их не пришлось.</div>

# %%
df_2015[df_2015['platform']=='PS4'].plot(x='critic_score',
                               y='total_sales',
                               kind='scatter',
                               title='Зависимость продаж от оценок критиков',
                               figsize=(6,4),
                              ylabel='Продажи, млн шт',
                              xlabel='Оценка критиков')

plt.show()

print('Коэффициент корреляции Пирсона: ',
      df_2015[df_2015['platform']=='PS4']['total_sales'].corr(
          df_2015[df_2015['platform']=='PS4']['critic_score']))
# Out:
# Коэффициент корреляции Пирсона:  0.40266141068104083

# %% [markdown]
# Диаграммы показывают, что между оценками критиков и продажами есть прямая, средне-слабая корреляция. Оценки пользователей корреляции с продажами не имеют.
#
# Посмотрим, случаен ли такой вывод или это общая тенденция для всех платформ.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Дьявол кроется в формулировках: **оценки критиков существенно влияют на продажи** - говорить так в общем случае неверно.
#
# ---
#
# Формулировать, что коэффициент  корреляции (Пирсона) между 2 переменными (в нашем случае между "total_sales" и "critic_score") есть показатель того, что **на количество продаж влияет оценка ** - неверно. Корреляция не подразумевает наличие причинно-следственной связи между переменными.
#
# Коэффициент свидетельствует **о наличии или отсутствии линейной связи** между переменными, и **измеряет выраженность** этой связи. Другими словами, коэффициент корреляции - это инструмент, с помощью которого можно проверить гипотезу о **линейной** зависимости и измерить степень этой зависимости.
#
# Например, в нашем случае, связь между продажами и оценками экспертов для всех платформ является **прямой, слабой** степени выраженности (во всех случаях коэффициент около 0,3-0,4).
#
# Я бы твою фразу переписал бы так (**ПРИМЕР**): "Оценки критиков демонстрируют прямую, средне-слабую корреляцию с "цифрами" продаж. Оценки пользователей корреляции с продажами не имеют".
#
# Понимаешь, нет влияния оценок на продажи. Коэффициент корреляции Пирсона не про это. Он про линейную зависимость 2-х переменных. И ещё, это коэффициент **НЕ ОБЪЯСНЯЕТ** зависимость, он **НЕ ГОВОРИТ** почему наблюдается такой эффект, но просто констатирует факт, что корреляция наблюдается (например, "мы видим, что те игры, которым наши эксперты дают высокие оценки - продаются лучше". А вот почему они продаются лучше - можно только предполагать ... разные причины могут быть). Вот смешная статейка на эту тему: https://ktonanovenkogo.ru/voprosy-i-otvety/korrelyaciya-chto-ehto-takoe-prostymi-slovami.html</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %%
for p in df_2015['platform'].unique():
    df_2015[df_2015['platform']==p].plot(x='user_score',
                               y='total_sales',
                               kind='scatter',
                               title=p + '. Зависимость продаж от пользовательских оценок',
                               figsize=(6,4),
                              ylabel='Продажи, млн шт',
                              xlabel='Оценка пользователей')
    
    plt.show()
    
    print('Коэффициент корреляции Пирсона: ', 
          df_2015[df_2015['platform']==p]['total_sales'].corr(df_2015[df_2015['platform']==p]['user_score']))

    df_2015[df_2015['platform']==p].plot(x='critic_score',
                               y='total_sales',
                               kind='scatter',
                               title=p + '. Зависимость продаж от оценок критиков',
                               figsize=(6,4),
                              ylabel='Продажи, млн шт',
                              xlabel='Оценка критиков')
    
    plt.show()
    
    print('Коэффициент корреляции Пирсона: ', 
          df_2015[df_2015['platform']==p]['total_sales'].corr(df_2015[df_2015['platform']==p]['critic_score']))
# Out:
# Коэффициент корреляции Пирсона:  -0.040131589472697356
# Коэффициент корреляции Пирсона:  0.40266141068104083
# Коэффициент корреляции Пирсона:  0.2151932718527028
# Коэффициент корреляции Пирсона:  0.31411749286905105
# Коэффициент корреляции Пирсона:  -0.0703839280647581
# Коэффициент корреляции Пирсона:  0.42867694370333226
# Коэффициент корреляции Пирсона:  0.4079264579217078
# Коэффициент корреляции Пирсона:  0.370201412480884
# Коэффициент корреляции Пирсона:  -0.16676141347662116
# Коэффициент корреляции Пирсона:  0.44657460493190704
# Коэффициент корреляции Пирсона:  -0.138444570945665
# Коэффициент корреляции Пирсона:  0.5257228356581523
# Коэффициент корреляции Пирсона:  -0.06641717858906729
# Коэффициент корреляции Пирсона:  0.17727193487623283
# Коэффициент корреляции Пирсона:  1.0
# Коэффициент корреляции Пирсона:  nan
# Коэффициент корреляции Пирсона:  -0.16845504978064446
# Коэффициент корреляции Пирсона:  0.04266490657009526

# %% [markdown]
# Получается, что прямая слабая или средне-слабая корреляция есть между оценками критиков и продажами только у популярных платформ: `PC`, `PS3`, `PS4`, `XOne`, `X360`. У менее популярных платформ наблюдается также средне-слабая корреляция между продажами и  оценками пользователей - `WiiU`, `3DS`. У игр платформы `Wii` в нашем датасете слишком мало экспертных оценок и совсем нет пользовательских оценок.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Неверные формулировки, нужно исправить (см. красный комментарий выше).
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %% [markdown]
# ### Популярные жанры

# %% [markdown]
# Выясним, какие игровые жанры являются самыми популярными, для этого выведем медианные значения продаж по каждому жанру.

# %%
df_2015.pivot_table(
    index='genre',
    values='total_sales',
    aggfunc='median').reset_index().sort_values(
        by='total_sales', 
        ascending=False).plot(
            x='genre',
            title='Продажи по жанрам',
            kind='bar',
            figsize=(16, 8),
            xlabel='Жанр', 
            ylabel='Продажи, млн шт',
            legend=False,
            rot=360)
plt.show()

# %% [markdown]
# Самыми прибыльными жанрами являются Shooter, Sports и Platform.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь у нас возникла проблема: по суммарным (sum, count) объемам продаж у тебя получилось, что явный лидер - игры в жанре Экшн. Если же ты рассмотришь медианные или средние (mean) значения, то результат поменяется в пользу Шуттеров. Учти тот факт, что игр в жанре Экшн выпускается значительно больше, чем других (в 1,5-2 раза). Доля количества игр в жанре «стрелялок» - всего лишь 8%. Очевидно, что в жанре Экшн присутствует большое количество непопулярных игр с низкими объёмами продаж, в результате чего общий объём продаж жанра "раздут" и берётся количеством, а не качеством. Медиана учитывает не только слишком большие\маленькие значения относительно среднего, но и их количество. Поэтому брать итоговые результаты медианы или среднего более корректно.
#
# В сухом остатке: попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи). Я думаю, что анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.</div>
#
#
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, исправила </font>
# </div>

# %% [markdown]
# ### Портерт пользователей из разных регионов

# %% [markdown]
# Исследуем, как меняются предпочтения пользователей в зависимости от региона - Северная Америка, Европа и Япония.

# %%
region_sales = pd.DataFrame({'sales': [sum(df_2015['na_sales']),
                                       sum(df_2015['eu_sales']),
                                       sum(df_2015['jp_sales'])]},
                  index=['Северная Америка', 'Европа', 'Япония'])

region_sales.plot.pie(y='sales', figsize=(7, 7),legend=False, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Во-первых, отметим, что большая часть всех продаж приходится на Северную Америку и Европу, а на Японию - всего лишь седьмая часть.

# %%
regions={'na': 'Северная Америка','eu': 'Европа','jp': 'Япония'}

for region in regions:
    df_2015.pivot_table(
        index='genre',
        values=region+'_sales',
        aggfunc='median').reset_index().sort_values(
            by=region+'_sales', 
            ascending=False).plot(
                x='genre',
                title='Продажи по жанрам. '+regions[region],
                kind='bar',
                figsize=(16, 8),
                xlabel='Жанр',
                ylabel='Продажи, млн шт',
                legend=False,
                rot=360)
    
    plt.show()
    
    df_2015.pivot_table(
        index='platform',
        values=region+'_sales',
        aggfunc='sum').reset_index().sort_values(
            by=region+'_sales', 
            ascending=False).plot(
                x='platform',
                title='Продажи по платформам. '+regions[region],
                kind='bar',
                figsize=(16, 8),
                xlabel='Платформа',
                ylabel='Продажи, млн шт',
                legend=False,
                rot=360)
    
    plt.show()
    
    df_2015.pivot_table(
        index='rating',
        values=region+'_sales',
        aggfunc='sum').reset_index().sort_values(
            by=region+'_sales', 
            ascending=False).plot(
                x='rating',
                title='Продажи по рейтингу ESRB. '+regions[region],
                kind='bar',
                figsize=(8, 4),
                xlabel='Рейтинг',
                ylabel='Продажи, млн шт',
                legend=False,
                rot=360)
    
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Один из подводных камней этого проекта. Суть его в том, что часто студенты в самом начале «тетрадки» пропуски в 'rating' не обрабатывают, оставляют NaN, и соответственно во время анализ и/или построении графиков игры без рейтингов «теряются».</div>

# %% [markdown]
# Портрет игрока в Северной Америке:
# - любимые жанры: Shooter, Platform, Sports, Fighting, Racing
# - самые популярные платформы: PS4, Xone, X360, 3DS, PS3
#
# Портрет игрока в Европе:
# - любимые жанры: Shooter, Platform, Racing, Sports, Simulation
# - самые популярные платформы: PS4, Xone, PS3, PC, 3DS
#
#
# В Японии другая картина:
# - любимые жанры: Role-Playing, Fighting, Puzzle, Misc, Action
# - популярные платформы: 3DS, PS4, PSV, PS3, WiiU
#
# Заметим также, что в Японии преобладающее большинство проданных игр не имеют значения рейтинга по системе ESRB. Как и было замечено ранее, это объясняется тем, что в Япониии популярны совсем другие игры, чем в остальном мире, и американское агентство оценки игр их не оценивает.
#
# Имеет смысл пересмотреть график продаж по платформам только в Японии.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# А где вывод по этому пункту из брифа проекта?
#
# ![image.png](attachment:image.png)</div>
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Спасибо, добавила </font>
# </div>

# %%
df_2015.pivot_table(
    index='year_of_release',
    columns='platform',
    values='jp_sales',
    aggfunc='sum').plot(
        title='Продажи по платформам в Японии',
        style='o-',
        figsize=(16, 8),
        xlim=(2013, 2017),
        alpha=0.6,
        linewidth=3,
        xlabel='Год выпуска',
        ylabel='Продажи, млн шт')
plt.show()

# %% [markdown]
# Оказывается, в Японии набирает популярность новая платформа WiiU и PS4. А вот на PC и Xbox в Японии почти не играют.

# %% [markdown]
# **Вывод**
#
# В ходе исследовательского анализа выявлено следующее:
# 1. Новые платформы сменяют старые примерно за 10 лет. Это не относится к PC - игры на персональных компьютерах всё ещё выходят, хоть и уступают по продажам играм на других платформах.
# 2. По потенциальной успешности к 2017 году лидируют две платформы - PS4 и Xbox One, а также WiiU для Японии. Их предшественницы PS3, Xbox 360 и Wii плавно теряют свою популярность.
# 3. На продажи игр популярных платформ влияют оценки критиков и почти не влияют оценки пользователей. Однако оценки пользователей влияют на продажи игр японских платформ, таких как WiiU, 3DS, Wii.
# 4. Самые популярные жанры видеоигр - Shooter, Sports, Platform.
# 5. В разрезе регионов такая картина сохраняется для Северной Америки и Европы, однако в Японии свои лидеры - Role-Playing, Fighting и Puzzle.

# %% [markdown]
# ## Статистический анализ

# %% [markdown]
# Проведём статистический анализ и проверим две гипотезы.
#
# 1. Продажи в Северной Америке и Европе примерно одинаковы по объёму. Значит ли это, что средние пользовательские оценки игр пятых по популярности платформ в этих странах - XOne и PC - одинаковы?
# 2. Проверим, верно ли считать, что жанр Action действительно популярнее жанра Sports, т.е. что средние пользовательские рейтинги выше у жанра Action.

# %% [markdown]
# Исследуем характеристики выборок с данными по играм на Xbox One и играм на PC.

# %%
print('Количество пользовательских оценок игр на Xbox One:',
      df_2015[(df_2015['platform']=='XOne')]['user_score'].count())

print('Средняя оценка:',
      df_2015[(df_2015['platform']=='XOne')]['user_score'].mean())

print('Выборочная дисперсия:',
      np.var(df_2015[(df_2015['platform']=='XOne')]['user_score'], ddof=1))

print('Выборочное стандартное отклонение:',
      np.std(df_2015[(df_2015['platform']=='XOne')]['user_score'], ddof=1))

print()

print('Количество пользовательских оценок игр на PC:',
      df_2015[(df_2015['platform']=='PC')]['user_score'].count())

print('Средняя оценка:',
      df_2015[(df_2015['platform']=='PC')]['user_score'].mean())

print('Выборочная дисперсия:',
      np.var(df_2015[(df_2015['platform']=='PC')]['user_score'], ddof=1))

print('Выборочное стандартное отклонение:',
      np.std(df_2015[(df_2015['platform']=='PC')]['user_score'], ddof=1))

print()
# Out:
# Количество пользовательских оценок игр на Xbox One: 165
# Средняя оценка: 6.594545454545454
# Выборочная дисперсия: 1.8910066518847009
# Выборочное стандартное отклонение: 1.3751387755003859
#
# Количество пользовательских оценок игр на PC: 123
# Средняя оценка: 6.316260162601626
# Выборочная дисперсия: 2.9167826202852196
# Выборочное стандартное отклонение: 1.7078590750659786

# %% [markdown]
# Оценок игр на PC больше примерно в 3 раза. Судя по данным выборок, средняя пользовательская оценка игр двух платформ примерно одинакова.

# %% [markdown]
# Сформулируем **нулевую гипотезу**.
#
#     H₀: Средняя пользовательская оценка игр на XOne и игр на PC одинакова.
#
# **Альтерантивная гипотеза**.
#
#     H₁: Средняя пользовательская оценка игр на XOne и игр на PC отличается.
#
# Проверим, следует ли отклонять нулевую гипотезу - проведём Т-тест для независимых выборок. Т.к. размер выборок и их дисперсии отличаются, следует передать параметру `equal_var` значение `False`.
#
# В качестве значения уровня статистической значимости возьмём 5%.

# %%
alpha = .05 # уровень статистической значимости

results = st.ttest_ind(
    df_2015[df_2015['platform']=='XOne']['user_score'].dropna(),
    df_2015[df_2015['platform']=='PC']['user_score'].dropna(),
    equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не отвергаем нулевую гипотезу")
# Out:
# p-значение: 0.13923712043548309
# Не отвергаем нулевую гипотезу

# %% [markdown]
# Отвергнуть нулевую гипотезу не удалось, значит мы не можем утверждать, что средняя оценка пользователей игр на PC отличается от средней оценки пользователей игр на XOne.
#
# Теперь выведем характеристики выборок с данными по играм в жанре Action и Sports.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки» / NaN значения.
#
# Также верно и то, что мы используем здесь двусторонний тест.
#
# Ну и отлично, что ты понимаешь, что нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».</div>

# %%
print('Количество пользовательских оценок игр в жанре Action:',
      df_2015[(df_2015['genre']=='Action')]['user_score'].count())

print('Средняя оценка:',
      df_2015[(df_2015['genre']=='Action')]['user_score'].mean())

print('Выборочная дисперсия:',
      np.var(df_2015[(df_2015['genre']=='Action')]['user_score'], ddof=1))

print('Выборочное стандартное отклонение:',
      np.std(df_2015[(df_2015['genre']=='Action')]['user_score'], ddof=1))

print()

print('Количество пользовательских оценок игр в жанре Sports:',
      df_2015[(df_2015['genre']=='Sports')]['user_score'].count())

print('Средняя оценка:',
      df_2015[(df_2015['genre']=='Sports')]['user_score'].mean())

print('Выборочная дисперсия:',
      np.var(df_2015[(df_2015['genre']=='Sports')]['user_score'], ddof=1))

print('Выборочное стандартное отклонение:',
      np.std(df_2015[(df_2015['genre']=='Sports')]['user_score'], ddof=1))

print()
# Out:
# Количество пользовательских оценок игр в жанре Action: 298
# Средняя оценка: 6.766442953020134
# Выборочная дисперсия: 1.9022371364653246
# Выборочное стандартное отклонение: 1.3792161311648456
#
# Количество пользовательских оценок игр в жанре Sports: 127
# Средняя оценка: 5.225196850393701
# Выборочная дисперсия: 3.4469791276090485
# Выборочное стандартное отклонение: 1.8566041925001269

# %% [markdown]
# Оценок игр в жанре Action в два раза больше, средняя пользовательская оценка игр в этом жанре чуть больше оценки игр в жанре Sports.
#
# Сформулируем **нулевую гипотезу**.
#
#     H₀: Средняя пользовательская оценка игр в жанре Action и игр в жанре Sports одинакова.
#
# **Альтерантивная гипотеза**.
#
#     H₁: Средняя пользовательская оценка игр в жанре Action выше оценки игр в жанре Sports.
#
# Проверим, следует ли отклонять нулевую гипотезу - проведём Т-тест для независимых выборок. Т.к. размер выборок и их дисперсии отличаются, следует передать параметру `equal_var` значение `False`.
#
# В качестве значения уровня статистической значимости возьмём 5%.

# %%
alpha = .05 # уровень статистической значимости

results = st.ttest_ind(
    df_2015[df_2015['genre']=='Action']['user_score'].dropna(),
    df_2015[df_2015['genre']=='Sports']['user_score'].dropna(),
    equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не отвергаем нулевую гипотезу")
# Out:
# p-значение: 9.658176026869598e-15
# Отвергаем нулевую гипотезу

# %% [markdown]
# Оказывается, средние оценки пользователей по двум жанрам сильно отличаются, значит, вывод, сделанный нами после исследовательского анализа, не случаен, и жанр Action действительно популярнее жанра Sports.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Итак, в ходе проекта мы:
#
# - получили данные по продажам и оценкам видеоигр с 1980 по 2016 год;
# - осмотрели данные на предмет ошибок, пропусков и дублей, часть данных восстановили, обобщили возрастные рейтинги более укрупнёнными категориями и привели данные к корректным типам;
# - выявили актуальный период - последние 3 года;
# - выявили актуальные платформы, для которых сейчас разрабатываются игры - PlayStation 3, PlayStation 4, PlayStation Vita, PC, Xbox 360, Xbox One, Nintendo Wii, Nintendo WiiU, Nintendo 3DS;
# - провели исследовательский анализ и выяснили, что
#     - по потенциальной успешности к 2017 году лидируют две платформы - PS4 и Xbox One, а в Японии - WiiU, хотя 3DS, выстрелив в 2012-2013 годах всё ещё держится на ведущих позициях по продажам;
#     - в Японии не играют на PC и Xbox;
#     - самые популярные жанры - Shooter, Platform, Racing и Sports для Северной Америки и Европы, а в Японии лидируют Role-Playing, Fighting и Puzzle;
#     - на продажи PlayStation и Xbox влияют оценки критиков, а на продажи игр для Nintendo, которые популярны в Японии - оценки пользователей;
# - проверили выдвинутые гипотезы на статистических тестах и сделали вывод, что жанр Action действительно популярнее жанра Sports.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# После исправления красных комментариев надо будет ещё раз пересмотреть выводы в этом финальном разделе, возможно какие-то акценты сместятся ... возможно что-то измениться?</div>

# %% [markdown]
# # Результат ревью:
#
# Софья, я отмечаю высокий уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib / seaborn), выбираешь для визуализации ровно те типы графиков, которые нужны. Очень хорошо, что оси на графиках подписаны и сами они имеют понятные названия.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. Заполнять пропуски в рейтингах в этой задаче нельзя. Оцени пожалуйста корректность такого решения и рассмотри другой вариант работы с пропусками.
#
# 2. Одна из задач этого проекта (согласно брифа): 1. Объясните, почему заполнили пропуски определённым образом или почему не стали это делать, 2. Опишите причины, которые могли привести к пропускам 3. Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать. Нужен твой комментарий, касающийся природы пропусков в столбце с рейтингами, а именно, может ли быть какая-то связь с тем, что в столбце с рейтингами >40% пропусков и тем, что эти оценки (рейтинги) выставляет **именно Американское рейтинговое агентство?
#
# 3. Для анализа взят слишком большой интервал. Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал.
#
# 4. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 5. Формулировать, что коэффициент (линейной) корреляции (Пирсона) между 2 переменными (в нашем случае между "продажами" и "оценками") есть показатель **влияния оценок на количество продаж** - неверно.
#
# 6. Попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. Анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.</div>
#
# Эти 6 моментов требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: отличная работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Возможно их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
